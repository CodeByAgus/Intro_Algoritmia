# %%
# Ejercicio 1
# Leer los números de legajo de los alumnos de un curso y su nota de examen final.
# El fin de la carga se determina ingresando un -1 como legajo.
# Se debe validar que la nota ingresada sea entre 1 y 10.
# Terminada la carga de datos, recorrer las listas e informar:
#   - Cantidad de alumnos que aprobaron con nota mayor o igual a 4.
#   - Cantidad de alumnos que desaprobaron el examen (nota menor a 4).
#   - Promedio de nota y los legajos que superan el promedio.
#
# Luego mostrar un listado de manera ascendente según el número de legajo.
# Ingresar números de legajo hasta que se encuentre e informar la nota de examen final
# utilizando búsqueda binaria.
#
# Resolver de dos formas:
#   - Utilizando dos listas.
#   - Utilizando una matriz de dos filas.

# %%
# Ejercicio 2
# Una Administradora de Consorcios necesita un sistema para gestionar el cobro de las
# expensas de un edificio de departamentos de 20 unidades.
# En 2 listas se almacena: número de unidad y superficie en metros cuadrados.
# Validar que no se ingresen números de unidades duplicadas.
# Cada unidad paga un valor fijo para todo el edificio de expensas por metro cuadrado por mes.
#
# Se pide:
#   a) Informar el promedio de expensas del mes.
#   b) Ordenar los listados de mayor a menor según la superficie.
#      Mostrar por pantalla el listado ordenado informando Número de Unidad y Superficie en m².

# %%
# Ejercicio 3 - Hora de jugar
# Desarrollar un programa que genere un número entero al azar de cuatro cifras
# y proponerle al usuario que lo descubra, ingresando valores repetidamente hasta hallarlo.
# En cada intento el programa mostrará mensajes indicando si el número ingresado
# es mayor o menor que el valor secreto.
#
# Permitir que el usuario abandone al ingresar -1.
# Informar la cantidad de intentos realizada al terminar el juego.
# Si el usuario mejoró la mejor marca de intentos, solicitar su número de documento.
# Mostrar la lista ordenada de los 5 mejores puntajes (con sus dueños)
# y preguntar si se desea jugar otra vez, reiniciando el juego en caso afirmativo.

# %%
# Ejercicio 4
# Modificar el programa del Ejercicio 3 para que las pistas brindadas no sean
# 'es mayor' o 'es menor', sino 'M dígitos correctos y N dígitos aproximados'.
#
# Un dígito es CORRECTO cuando tanto su valor como su posición coinciden con los del número secreto.
# Un dígito es APROXIMADO cuando coincide el valor, pero no su posición.
#
# Ejemplos con número secreto 5739:
#   Intento 1: 1234 -> 1 correcto
#   Intento 2: 5678 -> 1 correcto y 1 aproximado
#   Intento 3: 9375 -> 4 aproximados

# %%
# Ejercicio 5
# Construir una lista llamada SECUENCIAS con N números enteros al azar entre 1 y 20.
# La lista se caracteriza porque sus valores deben encontrarse divididos en secuencias
# separadas por ceros, cuya suma no sea mayor que 20.
#
# Para eso se deberá agregar un elemento de valor 0 a fin de separar cada secuencia
# de la siguiente, cuidando que ninguna secuencia sume más de 20.
# Agregar un 0 adicional al final de la lista y mostrar la lista obtenida por pantalla.
#
# Ejemplo:
#   Lista original:  [5, 2, 9, 6, 4, 15, 3, 19, 12, 1, 5]
#   Resultado:       [5, 2, 9, 0, 6, 4, 0, 15, 3, 0, 19, 0, 12, 1, 5, 0]

# %%
"""Un club deportivo tiene una lista con los números de socio de las personas que se inscribieron para un 
torneo. Un socio ha decidido bajarse del torneo y el club necesita borrarlo de la lista.
Consigna:Escribir un programa en Python que realice las siguientes tareas utilizando funciones:
Crear una función para cargar una lista con números de socios (números enteros). La carga finaliza 
cuando se ingresa el número 0.
Crear una función llamada eliminar_socio que reciba la lista y el número de socio que se desea dar de 
baja.
Si el socio existe en la lista, debe eliminarlo y mostrar un mensaje de confirmación indicando en qué 
posición estaba.
Si el socio no existe, debe mostrar un mensaje de error que diga "El socio no se encuentra registrado".
La función debe retornar la lista modificada (o modificarla por referencia).
En el programa principal, mostrar la lista original, solicitar el socio a eliminar, 
llamar a la función y luego 
mostrar la lista final para verificar que el elemento realmente desapareció."""

socios= int(input("ingrese socio"))

while socios != 0:
    listado = [].append(socios)


def eliminar_socio(a):
    numl=int(input("ingrese numero de listado"))
    nums=int(input("ingrese numero de socio"))

    if numl > len(socios) or numl < len(socios):
        print("ERROR")
    elseif nums == 
    else

# %%
### 1. Función para cargar la lista
def cargar_socios():
    lista = []
    socio = int(input("Ingrese número de socio (0 para finalizar): "))
    
    while socio != 0:
        lista.append(socio)
        socio = int(input("Ingrese número de socio (0 para finalizar): "))
    return lista


def eliminar_socio(lista, numero_baja):
    if numero_baja in lista:
        # Buscamos en qué posición está (índice)
        posicion = lista.index(numero_baja)
        lista.remove(numero_baja)
        print(f"✔ Confirmación: El socio {numero_baja} fue eliminado. Estaba en la posición {posicion}.")
    else:
        print("Error")
        
    return lista

### --- PROGRAMA PRINCIPAL --- ###

print("--- SISTEMA DEL CLUB DEPORTIVO ---")
# Llamamos a la función para cargar los socios
listado_socios = cargar_socios()

# Mostramos la lista original
print("\nLista original de socios:", listado_socios)

# Solicitamos el socio a eliminar (si la lista no está vacía)
if len(listado_socios) > 0:
    socio_a_borrar = int(input("\nIngrese el número de socio que desea dar de baja: "))

    # Llamamos a la función de eliminar pasándole la lista y el número
    listado_socios = eliminar_socio(listado_socios, socio_a_borrar)

    # Mostramos la lista final para verificar
    print("Lista final de inscritos:", listado_socios)
else:
    print("No se ingresaron socios al torneo.")
# Out:
# --- SISTEMA DEL CLUB DEPORTIVO ---
#
# Lista original de socios: [12134, 12133, 35, 34567, 4]
# ✔ Confirmación: El socio 4 fue eliminado. Estaba en la posición 4.
# Lista final de inscritos: [12134, 12133, 35, 34567]
